# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv("/home/bunny/Downloads/dataset_2191_sleep.csv")
file
# Out:
#     body_weight  brain_weight max_life_span gestation_time  predation_index  \
# 0      6654.000        5712.0          38.6            645                3
# 1         1.000           6.6           4.5             42                3
# 2         3.385          44.5            14             60                1
# 3         0.920           5.7             ?             25                5
# 4      2547.000        4603.0            69            624                3
# ..          ...           ...           ...            ...              ...
# 57        2.000          12.3           7.5            200                3
# 58        0.104           2.5           2.3             46                3
# 59        4.190          58.0            24            210                4
# 60        3.500           3.9             3             14                2
# 61        4.050          17.0            13             38                3
#
#     sleep_exposure_index  danger_index total_sleep
# ...

# %%
file.dtypes
# Out:
# body_weight             float64
# brain_weight            float64
# max_life_span            object
# gestation_time           object
# predation_index           int64
# sleep_exposure_index      int64
# danger_index              int64
# total_sleep              object
# dtype: object

# %%
file['max_life_span'] = file['max_life_span'].replace('?', np.nan)
file['gestation_time'] = file['gestation_time'].replace('?',np.nan)
file['total_sleep'] = file['total_sleep'].replace('?',np.nan)

# %%
file = file.astype(float)

# %%
file.dtypes
# Out:
# body_weight             float64
# brain_weight            float64
# max_life_span           float64
# gestation_time          float64
# predation_index         float64
# sleep_exposure_index    float64
# danger_index            float64
# total_sleep             float64
# dtype: object

# %%
filter = ['body_weight','brain_weight','max_life_span','gestation_time','predation_index','sleep_exposure_index','total_sleep']
x = file[filter]
y = file['danger_index']

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
trainx,valx,trainy,valy = train_test_split(x,y,random_state=1)
trainx = trainx.replace(np.nan, 2.71)
valx = valx.replace(np.nan, 2.71)
trainy = trainy.replace(np.nan, 2.71)
valy = valy.replace(np.nan, 2.71)

# %%
model = GaussianNB()
model.fit(trainx, trainy)
# Out:
# GaussianNB()

# %%
print(valy, model.predict(valx))
# Out:
# 21    5.0
# 52    5.0
# 38    1.0
# 24    1.0
# 2     1.0
# 41    2.0
# 60    1.0
# 50    2.0
# 35    3.0
# 44    4.0
# 42    4.0
# 39    1.0
# 26    3.0
# 55    2.0
# 47    3.0
# 3     3.0
# Name: danger_index, dtype: float64 [5. 5. 2. 1. 2. 2. 2. 2. 2. 4. 4. 2. 4. 2. 2. 4.]
